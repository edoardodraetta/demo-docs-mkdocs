# %% [markdown]
# # Basic Operations Tutorial
#
# Learn how to use the basic math operations.

# %%
from mypackage import add, multiply

# Let's add some numbers
result = add(10, 20)
print(f"10 + 20 = {result}")

# %%
# Now multiply
result = multiply(5, 6)
print(f"5 × 6 = {result}")
